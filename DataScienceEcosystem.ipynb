# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarised.

# %% [markdown]
# **Objectives**
# - List languages used by data scientists
# - List libraries used by data scientists
# - List open source development tools used in data science
# - Perform arthimetic expressions

# %% [markdown]
# Some of the popular languages that data scientists use are:
# 1. Python
# 2. SQL
# 3. R
# 4. Java
# 5. Scala
# 6. Julia
# 7. C++
# 8. JavaScript

# %% [markdown]
# There are several libraries commonly used by data scientists. These include:
# 1. Scientific Computing Libraries
# 2. Visualisation Libraries
# 3. Machine Learning Libraries
# 4. Deep Learning Libraries

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |Watson Studio|
# |Watson OpenScale|
# |IBM AutoAI|

# %% [markdown]
# ### The examples below are instances of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
200/60
# Out:
# 3.3333333333333335

# %%
print(str(200/60) + " hrs")
# Out:
# 3.3333333333333335 hrs

# %% [markdown]
# ## Author
# Zainab Riaz
